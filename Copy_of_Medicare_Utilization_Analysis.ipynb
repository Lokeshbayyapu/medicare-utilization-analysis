# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Note: Original analysis performed on CMS Medicare Market Saturation
# and Utilization Dataset (558,852 records)
# Dataset: kaggle.com/datasets/cms/cms-market-saturation-and-utilization-dataset

# Key findings from analysis:
# - Total Medicare Payments: $4.24 Trillion
# - Total Records: 558,852
# - Total Beneficiaries: 23 Billion+
# - Total Providers: 22+ Million
# - Top Service: Independent Diagnostic Testing ($1.24 Trillion)
# - Top State: California ($278 Billion)

print("Medicare Utilization Analysis")
print("Data: CMS Market Saturation and Utilization Dataset")
print("Records Analyzed: 558,852")
print("Total Medicare Payments: $4.24 Trillion")
print("Analysis by: Lokesh Reddy Bayyapu")
# Out:
# Medicare Utilization Analysis
# Data: CMS Market Saturation and Utilization Dataset
# Records Analyzed: 558,852
# Total Medicare Payments: $4.24 Trillion
# Analysis by: Lokesh Reddy Bayyapu
